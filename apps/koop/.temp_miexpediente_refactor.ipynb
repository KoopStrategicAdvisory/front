# %%
import pathlib
from pathlib import Path

root = Path('c:/Workspace/koop/front')
page_path = root / 'src' / 'pages' / 'dinamic' / 'Miexpediente' / 'index.jsx'
hook_path = root / 'src' / 'hooks' / 'useMiExpediente.js'

print('Page exists:', page_path.exists())
print('Hook exists:', hook_path.exists())
print('Page size:', page_path.stat().st_size if page_path.exists() else 'n/a')
print('Hook size:', hook_path.stat().st_size if hook_path.exists() else 'n/a')
